# %% [markdown]
# This is a companion notebook for the book [Deep Learning with Python, Second Edition](https://www.manning.com/books/deep-learning-with-python-second-edition?a_aid=keras&a_bid=76564dff). For readability, it only contains runnable code blocks and section titles, and omits everything else in the book: text paragraphs, figures, and pseudocode.
#
# **If you want to be able to follow what's going on, I recommend reading the notebook side by side with your copy of the book.**
#
# This notebook was generated for TensorFlow 2.6.

# %% [markdown]
# # Introduction to deep learning for computer vision

# %% [markdown]
# ## Introduction to convnets

# %% [markdown]
# **Instantiating a small convnet**

# %%
from tensorflow import keras
from tensorflow.keras import layers
inputs = keras.Input(shape=(28, 28, 1))
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(inputs)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.Flatten()(x)
outputs = layers.Dense(10, activation="softmax")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

# %% [markdown]
# **Displaying the model's summary**

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 3, 3, 128)         73856
#
#  flatten (Flatten)           (None, 1152)              0
#
#  dense (Dense)               (None, 10)                11530
#
# =================================================================
# Total params: 104,202
# Trainable params: 104,202
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Training the convnet on MNIST images**

# %%
from tensorflow.keras.datasets import mnist

(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
train_images = train_images.reshape((60000, 28, 28, 1))
train_images = train_images.astype("float32") / 255
test_images = test_images.reshape((10000, 28, 28, 1))
test_images = test_images.astype("float32") / 255
model.compile(optimizer="rmsprop",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"])
model.fit(train_images, train_labels, epochs=5, batch_size=64)
# Out:
# Epoch 1/5
# 938/938 [==============================] - 17s 17ms/step - loss: 0.1533 - accuracy: 0.9539
# Epoch 2/5
# 938/938 [==============================] - 16s 17ms/step - loss: 0.0447 - accuracy: 0.9863
# Epoch 3/5
# 938/938 [==============================] - 16s 17ms/step - loss: 0.0317 - accuracy: 0.9902
# Epoch 4/5
# 938/938 [==============================] - 16s 17ms/step - loss: 0.0238 - accuracy: 0.9926
# Epoch 5/5
# 938/938 [==============================] - 16s 17ms/step - loss: 0.0186 - accuracy: 0.9947

# %% [markdown]
# **Evaluating the convnet**

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0235 - accuracy: 0.9919
# Test accuracy: 0.992

# %% [markdown]
# ### The convolution operation

# %% [markdown]
# #### Understanding border effects and padding

# %% [markdown]
# #### Understanding convolution strides

# %% [markdown]
# ### The max-pooling operation

# %% [markdown]
# **An incorrectly structured convnet missing its max-pooling layers**

# %%
inputs = keras.Input(shape=(28, 28, 1))
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(inputs)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.Flatten()(x)
outputs = layers.Dense(10, activation="softmax")(x)
model_no_max_pool = keras.Model(inputs=inputs, outputs=outputs)

# %%
model_no_max_pool.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_3 (Conv2D)           (None, 26, 26, 32)        320
#
#  conv2d_4 (Conv2D)           (None, 24, 24, 64)        18496
#
#  conv2d_5 (Conv2D)           (None, 22, 22, 128)       73856
#
#  flatten_1 (Flatten)         (None, 61952)             0
#
#  dense_1 (Dense)             (None, 10)                619530
#
# =================================================================
# Total params: 712,202
# Trainable params: 712,202
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Training a convnet from scratch on a small dataset

# %% [markdown]
# ### The relevance of deep learning for small-data problems

# %% [markdown]
# ### Downloading the data

# %% [markdown]
# **Copying images to training, validation, and test directories**

# %%
import os, shutil, pathlib

original_dir = pathlib.Path("train")
new_base_dir = pathlib.Path("cats_vs_dogs_small")

def make_subset(subset_name, start_index, end_index):
    for category in ("cat", "dog"):
        dir = new_base_dir / subset_name / category
        os.makedirs(dir)
        fnames = [f"{category}.{i}.jpg" for i in range(start_index, end_index)]
        for fname in fnames:
            shutil.copyfile(src=original_dir / fname,
                            dst=dir / fname)

make_subset("train", start_index=0, end_index=1000)
make_subset("validation", start_index=1000, end_index=1500)
make_subset("test", start_index=1500, end_index=2500)

# %% [markdown]
# ### Building the model

# %% [markdown]
# **Instantiating a small convnet for dogs vs. cats classification**

# %%
from tensorflow import keras
from tensorflow.keras import layers

inputs = keras.Input(shape=(180, 180, 3))
x = layers.Rescaling(1./255)(inputs)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.Flatten()(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 180, 180, 3)]     0
#
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d_6 (Conv2D)           (None, 178, 178, 32)      896
#
#  max_pooling2d_2 (MaxPooling  (None, 89, 89, 32)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 87, 87, 64)        18496
#
#  max_pooling2d_3 (MaxPooling  (None, 43, 43, 64)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 41, 41, 128)       73856
#
#  max_pooling2d_4 (MaxPooling  (None, 20, 20, 128)      0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 18, 18, 256)       295168
#
#  max_pooling2d_5 (MaxPooling  (None, 9, 9, 256)        0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 7, 7, 256)         590080
#
#  flatten_2 (Flatten)         (None, 12544)             0
#
#  dense_2 (Dense)             (None, 1)                 12545
#
# =================================================================
# Total params: 991,041
# Trainable params: 991,041
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Configuring the model for training**

# %%
model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

# %% [markdown]
# ### Data preprocessing

# %% [markdown]
# **Using `image_dataset_from_directory` to read images**

# %%
from tensorflow.keras.utils import image_dataset_from_directory

train_dataset = image_dataset_from_directory(
    new_base_dir / "train",
    image_size=(180, 180),
    batch_size=32)
validation_dataset = image_dataset_from_directory(
    new_base_dir / "validation",
    image_size=(180, 180),
    batch_size=32)
test_dataset = image_dataset_from_directory(
    new_base_dir / "test",
    image_size=(180, 180),
    batch_size=32)
# Out:
# Found 2000 files belonging to 2 classes.
# Found 1000 files belonging to 2 classes.
# Found 2000 files belonging to 2 classes.

# %%
import numpy as np
import tensorflow as tf
random_numbers = np.random.normal(size=(1000, 16))
dataset = tf.data.Dataset.from_tensor_slices(random_numbers)

# %%
for i, element in enumerate(dataset):
    print(element.shape)
    if i >= 2:
        break
# Out:
# (16,)
# (16,)
# (16,)

# %%
batched_dataset = dataset.batch(32)
for i, element in enumerate(batched_dataset):
    print(element.shape)
    if i >= 2:
        break
# Out:
# (32, 16)
# (32, 16)
# (32, 16)

# %%
reshaped_dataset = dataset.map(lambda x: tf.reshape(x, (4, 4)))
for i, element in enumerate(reshaped_dataset):
    print(element.shape)
    if i >= 2:
        break
# Out:
# (4, 4)
# (4, 4)
# (4, 4)

# %% [markdown]
# **Displaying the shapes of the data and labels yielded by the `Dataset`**

# %%
for data_batch, labels_batch in train_dataset:
    print("data batch shape:", data_batch.shape)
    print("labels batch shape:", labels_batch.shape)
    break
# Out:
# data batch shape: (32, 180, 180, 3)
# labels batch shape: (32,)

# %% [markdown]
# **Fitting the model using a `Dataset`**

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="convnet_from_scratch.keras",
        save_best_only=True,
        monitor="val_loss")
]
history = model.fit(
    train_dataset,
    epochs=30,
    validation_data=validation_dataset,
    callbacks=callbacks)
# Out:
# Epoch 1/30
# 63/63 [==============================] - 36s 555ms/step - loss: 0.7961 - accuracy: 0.5140 - val_loss: 0.6874 - val_accuracy: 0.5960
# Epoch 2/30
# 63/63 [==============================] - 34s 534ms/step - loss: 0.7019 - accuracy: 0.5535 - val_loss: 0.6809 - val_accuracy: 0.5800
# Epoch 3/30
# 63/63 [==============================] - 35s 548ms/step - loss: 0.6843 - accuracy: 0.5915 - val_loss: 0.6378 - val_accuracy: 0.6190
# Epoch 4/30
# 63/63 [==============================] - 35s 552ms/step - loss: 0.6487 - accuracy: 0.6485 - val_loss: 0.6625 - val_accuracy: 0.5870
# Epoch 5/30
# 63/63 [==============================] - 35s 547ms/step - loss: 0.6030 - accuracy: 0.6775 - val_loss: 0.6298 - val_accuracy: 0.6720
# Epoch 6/30
# 63/63 [==============================] - 34s 547ms/step - loss: 0.5574 - accuracy: 0.7260 - val_loss: 1.1169 - val_accuracy: 0.6200
# Epoch 7/30
# 63/63 [==============================] - 34s 546ms/step - loss: 0.5396 - accuracy: 0.7505 - val_loss: 0.7665 - val_accuracy: 0.6870
# Epoch 8/30
# 63/63 [==============================] - 33s 520ms/step - loss: 0.4827 - accuracy: 0.7775 - val_loss: 0.6761 - val_accuracy: 0.6580
# Epoch 9/30
# 63/63 [==============================] - 33s 516ms/step - loss: 0.4399 - accuracy: 0.7975 - val_loss: 0.7508 - val_accuracy: 0.6810
# Epoch 10/30
# 63/63 [==============================] - 33s 518ms/step - loss: 0.3881 - accuracy: 0.8230 - val_loss: 0.6267 - val_accuracy: 0.7270
# Epoch 11/30
# 63/63 [==============================] - 35s 556ms/step - loss: 0.3236 - accuracy: 0.8610 - val_loss: 0.7638 - val_accuracy: 0.6940
# Epoch 12/30
# 63/63 [==============================] - 34s 542ms/step - loss: 0.2603 - accuracy: 0.8885 - val_loss: 0.8728 - val_accuracy: 0.6880
# Epoch 13/30
# 63/63 [==============================] - 34s 539ms/step - loss: 0.2118 - accuracy: 0.9105 - val_loss: 0.8011 - val_accuracy: 0.7420
# Epoch 14/30
# 63/63 [==============================] - 34s 538ms/step - loss: 0.1819 - accuracy: 0.9305 - val_loss: 0.8054 - val_accuracy: 0.7660
# Epoch 15/30
# 63/63 [==============================] - 34s 533ms/step - loss: 0.1717 - accuracy: 0.9415 - val_loss: 0.9520 - val_accuracy: 0.7710
# Epoch 16/30
# 63/63 [==============================] - 33s 516ms/step - loss: 0.1188 - accuracy: 0.9525 - val_loss: 1.1851 - val_accuracy: 0.7510
# Epoch 17/30
# 63/63 [==============================] - 33s 524ms/step - loss: 0.0914 - accuracy: 0.9700 - val_loss: 2.1114 - val_accuracy: 0.7010
# Epoch 18/30
# 63/63 [==============================] - 35s 551ms/step - loss: 0.0924 - accuracy: 0.9665 - val_loss: 1.4116 - val_accuracy: 0.7240
# Epoch 19/30
# 63/63 [==============================] - 34s 538ms/step - loss: 0.0699 - accuracy: 0.9760 - val_loss: 1.6172 - val_accuracy: 0.7250
# Epoch 20/30
# 63/63 [==============================] - 34s 532ms/step - loss: 0.0579 - accuracy: 0.9845 - val_loss: 1.4850 - val_accuracy: 0.7530
# Epoch 21/30
# 63/63 [==============================] - 33s 524ms/step - loss: 0.0769 - accuracy: 0.9775 - val_loss: 1.3859 - val_accuracy: 0.7620
# Epoch 22/30
# 63/63 [==============================] - 33s 521ms/step - loss: 0.0600 - accuracy: 0.9870 - val_loss: 1.4433 - val_accuracy: 0.7600
# Epoch 23/30
# 63/63 [==============================] - 32s 513ms/step - loss: 0.0713 - accuracy: 0.9800 - val_loss: 1.6050 - val_accuracy: 0.7490
# Epoch 24/30
# 63/63 [==============================] - 33s 523ms/step - loss: 0.0552 - accuracy: 0.9815 - val_loss: 1.5809 - val_accuracy: 0.7500
# Epoch 25/30
# 63/63 [==============================] - 33s 530ms/step - loss: 0.0495 - accuracy: 0.9835 - val_loss: 1.9846 - val_accuracy: 0.7100
# Epoch 26/30
# 63/63 [==============================] - 34s 541ms/step - loss: 0.0346 - accuracy: 0.9895 - val_loss: 2.2994 - val_accuracy: 0.7390
# Epoch 27/30
# 63/63 [==============================] - 33s 521ms/step - loss: 0.0691 - accuracy: 0.9830 - val_loss: 1.7382 - val_accuracy: 0.7540
# Epoch 28/30
# 63/63 [==============================] - 33s 519ms/step - loss: 0.0517 - accuracy: 0.9830 - val_loss: 2.3944 - val_accuracy: 0.7550
# Epoch 29/30
# 63/63 [==============================] - 33s 530ms/step - loss: 0.0751 - accuracy: 0.9805 - val_loss: 1.8975 - val_accuracy: 0.7470
# Epoch 30/30
# 63/63 [==============================] - 34s 541ms/step - loss: 0.0544 - accuracy: 0.9880 - val_loss: 2.0753 - val_accuracy: 0.7520

# %% [markdown]
# **Displaying curves of loss and accuracy during training**

# %%
import matplotlib.pyplot as plt
accuracy = history.history["accuracy"]
val_accuracy = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(accuracy) + 1)
plt.plot(epochs, accuracy, "bo", label="Training accuracy")
plt.plot(epochs, val_accuracy, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %% [markdown]
# **Evaluating the model on the test set**

# %%
test_model = keras.models.load_model("convnet_from_scratch.keras")
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 63/63 [==============================] - 8s 124ms/step - loss: 0.6505 - accuracy: 0.6985
# Test accuracy: 0.698

# %% [markdown]
# ### Using data augmentation

# %% [markdown]
# **Define a data augmentation stage to add to an image model**

# %%
data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.1),
        layers.RandomZoom(0.2),
    ]
)

# %% [markdown]
# **Displaying some randomly augmented training images**

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_dataset.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_images[0].numpy().astype("uint8"))
        plt.axis("off")
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:5 out of the last 5 calls to <function pfor.<locals>.f at 0x0000022C47AEF0D0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:6 out of the last 6 calls to <function pfor.<locals>.f at 0x0000022C47AEF040> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.

# %% [markdown]
# **Defining a new convnet that includes image augmentation and dropout**

# %%
inputs = keras.Input(shape=(180, 180, 3))
x = data_augmentation(inputs)
x = layers.Rescaling(1./255)(x)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.Flatten()(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.

# %% [markdown]
# **Training the regularized convnet**

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="convnet_from_scratch_with_augmentation.keras",
        save_best_only=True,
        monitor="val_loss")
]
history = model.fit(
    train_dataset,
    epochs=100,
    validation_data=validation_dataset,
    callbacks=callbacks)
# Out:
# Epoch 1/100
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# 63/63 [==============================] - 39s 575ms/step - loss: 0.7043 - accuracy: 0.5145 - val_loss: 0.6904 - val_accuracy: 0.5500
# Epoch 2/100
# 63/63 [==============================] - 36s 564ms/step - loss: 0.6940 - accuracy: 0.5795 - val_loss: 0.6931 - val_accuracy: 0.5540
# Epoch 3/100
# 63/63 [==============================] - 35s 556ms/step - loss: 0.6703 - accuracy: 0.5955 - val_loss: 0.9396 - val_accuracy: 0.5700
# Epoch 4/100
# 63/63 [==============================] - 36s 577ms/step - loss: 0.6597 - accuracy: 0.6250 - val_loss: 0.6406 - val_accuracy: 0.6280
# Epoch 5/100
# 63/63 [==============================] - 36s 564ms/step - loss: 0.6524 - accuracy: 0.6230 - val_loss: 0.7529 - val_accuracy: 0.5990
# Epoch 6/100
# 63/63 [==============================] - 36s 563ms/step - loss: 0.6268 - accuracy: 0.6430 - val_loss: 0.7928 - val_accuracy: 0.5590
# Epoch 7/100
# 63/63 [==============================] - 35s 558ms/step - loss: 0.6319 - accuracy: 0.6605 - val_loss: 0.6155 - val_accuracy: 0.6530
# Epoch 8/100
# 63/63 [==============================] - 35s 559ms/step - loss: 0.5800 - accuracy: 0.6930 - val_loss: 0.7270 - val_accuracy: 0.6710
# Epoch 9/100
# 63/63 [==============================] - 36s 564ms/step - loss: 0.5729 - accuracy: 0.7135 - val_loss: 0.5620 - val_accuracy: 0.7080
# Epoch 10/100
# 63/63 [==============================] - 36s 571ms/step - loss: 0.5628 - accuracy: 0.7165 - val_loss: 0.5908 - val_accuracy: 0.6980
# Epoch 11/100
# 63/63 [==============================] - 36s 578ms/step - loss: 0.5320 - accuracy: 0.7345 - val_loss: 0.6174 - val_accuracy: 0.6700
# Epoch 12/100
# 63/63 [==============================] - 36s 564ms/step - loss: 0.5343 - accuracy: 0.7425 - val_loss: 0.5425 - val_accuracy: 0.7190
# Epoch 13/100
# 63/63 [==============================] - 36s 564ms/step - loss: 0.5111 - accuracy: 0.7570 - val_loss: 0.5061 - val_accuracy: 0.7420
# Epoch 14/100
# 63/63 [==============================] - 35s 558ms/step - loss: 0.4970 - accuracy: 0.7645 - val_loss: 0.5348 - val_accuracy: 0.7490
# Epoch 15/100
# 63/63 [==============================] - 36s 565ms/step - loss: 0.4871 - accuracy: 0.7735 - val_loss: 0.6247 - val_accuracy: 0.7220
# Epoch 16/100
# 63/63 [==============================] - 35s 563ms/step - loss: 0.4596 - accuracy: 0.7810 - val_loss: 0.5995 - val_accuracy: 0.7340
# Epoch 17/100
# 63/63 [==============================] - 36s 565ms/step - loss: 0.4538 - accuracy: 0.7835 - val_loss: 0.5507 - val_accuracy: 0.7520
# Epoch 18/100
# 63/63 [==============================] - 36s 574ms/step - loss: 0.4486 - accuracy: 0.7905 - val_loss: 0.6413 - val_accuracy: 0.7240
# Epoch 19/100
# 63/63 [==============================] - 37s 585ms/step - loss: 0.4569 - accuracy: 0.7875 - val_loss: 0.4798 - val_accuracy: 0.7850
# Epoch 20/100
# 63/63 [==============================] - 36s 576ms/step - loss: 0.4169 - accuracy: 0.8105 - val_loss: 0.5632 - val_accuracy: 0.7490
# Epoch 21/100
# 63/63 [==============================] - 35s 561ms/step - loss: 0.4085 - accuracy: 0.8185 - val_loss: 0.7024 - val_accuracy: 0.7200
# Epoch 22/100
# 63/63 [==============================] - 36s 563ms/step - loss: 0.3937 - accuracy: 0.8250 - val_loss: 0.5474 - val_accuracy: 0.7490
# Epoch 23/100
# 63/63 [==============================] - 35s 559ms/step - loss: 0.3776 - accuracy: 0.8290 - val_loss: 1.9865 - val_accuracy: 0.6610
# Epoch 24/100
# 63/63 [==============================] - 35s 561ms/step - loss: 0.4011 - accuracy: 0.8285 - val_loss: 0.5060 - val_accuracy: 0.8040
# Epoch 25/100
# 63/63 [==============================] - 35s 562ms/step - loss: 0.3864 - accuracy: 0.8185 - val_loss: 0.4938 - val_accuracy: 0.7840
# Epoch 26/100
# 63/63 [==============================] - 36s 567ms/step - loss: 0.3676 - accuracy: 0.8370 - val_loss: 0.5733 - val_accuracy: 0.7460
# Epoch 27/100
# 63/63 [==============================] - 36s 576ms/step - loss: 0.3628 - accuracy: 0.8465 - val_loss: 0.5421 - val_accuracy: 0.7720
# Epoch 28/100
# 63/63 [==============================] - 37s 593ms/step - loss: 0.3230 - accuracy: 0.8660 - val_loss: 0.5675 - val_accuracy: 0.7830
# Epoch 29/100
# 63/63 [==============================] - 37s 582ms/step - loss: 0.3632 - accuracy: 0.8485 - val_loss: 0.6035 - val_accuracy: 0.7800
# Epoch 30/100
# 63/63 [==============================] - 36s 567ms/step - loss: 0.3158 - accuracy: 0.8680 - val_loss: 0.6342 - val_accuracy: 0.7900
# Epoch 31/100
# 63/63 [==============================] - 36s 566ms/step - loss: 0.3143 - accuracy: 0.8730 - val_loss: 0.4831 - val_accuracy: 0.7860
# Epoch 32/100
# 63/63 [==============================] - 35s 560ms/step - loss: 0.3045 - accuracy: 0.8680 - val_loss: 0.5887 - val_accuracy: 0.7920
# Epoch 33/100
# 63/63 [==============================] - 35s 562ms/step - loss: 0.3017 - accuracy: 0.8815 - val_loss: 0.6708 - val_accuracy: 0.7580
# Epoch 34/100
# 63/63 [==============================] - 36s 565ms/step - loss: 0.2789 - accuracy: 0.8750 - val_loss: 1.0183 - val_accuracy: 0.7260
# Epoch 35/100
# 63/63 [==============================] - 36s 564ms/step - loss: 0.2853 - accuracy: 0.8790 - val_loss: 0.6912 - val_accuracy: 0.7800
# Epoch 36/100
# 63/63 [==============================] - 36s 563ms/step - loss: 0.2603 - accuracy: 0.8925 - val_loss: 0.6689 - val_accuracy: 0.7700
# Epoch 37/100
# 63/63 [==============================] - 36s 576ms/step - loss: 0.2713 - accuracy: 0.8905 - val_loss: 0.6658 - val_accuracy: 0.7770
# Epoch 38/100
# 63/63 [==============================] - 36s 573ms/step - loss: 0.2899 - accuracy: 0.8750 - val_loss: 0.5532 - val_accuracy: 0.7770
# Epoch 39/100
# 63/63 [==============================] - 35s 563ms/step - loss: 0.2493 - accuracy: 0.8915 - val_loss: 0.6321 - val_accuracy: 0.7980
# Epoch 40/100
# 63/63 [==============================] - 37s 582ms/step - loss: 0.2372 - accuracy: 0.9045 - val_loss: 0.7576 - val_accuracy: 0.7890
# Epoch 41/100
# 63/63 [==============================] - 36s 576ms/step - loss: 0.2258 - accuracy: 0.9025 - val_loss: 0.6771 - val_accuracy: 0.8000
# Epoch 42/100
# 63/63 [==============================] - 37s 591ms/step - loss: 0.2260 - accuracy: 0.9150 - val_loss: 0.7633 - val_accuracy: 0.8030
# Epoch 43/100
# 63/63 [==============================] - 36s 566ms/step - loss: 0.2245 - accuracy: 0.9080 - val_loss: 0.6401 - val_accuracy: 0.7980
# Epoch 44/100
# 63/63 [==============================] - 36s 565ms/step - loss: 0.2285 - accuracy: 0.9060 - val_loss: 0.6852 - val_accuracy: 0.8010
# Epoch 45/100
# 63/63 [==============================] - 36s 565ms/step - loss: 0.2561 - accuracy: 0.9070 - val_loss: 0.5643 - val_accuracy: 0.8030
# Epoch 46/100
# 63/63 [==============================] - 35s 560ms/step - loss: 0.2184 - accuracy: 0.9130 - val_loss: 0.6599 - val_accuracy: 0.7940
# Epoch 47/100
# 63/63 [==============================] - 36s 567ms/step - loss: 0.2135 - accuracy: 0.9085 - val_loss: 0.6822 - val_accuracy: 0.8200
# Epoch 48/100
# 63/63 [==============================] - 36s 567ms/step - loss: 0.1912 - accuracy: 0.9240 - val_loss: 0.8959 - val_accuracy: 0.7680
# Epoch 49/100
# 63/63 [==============================] - 35s 560ms/step - loss: 0.1894 - accuracy: 0.9235 - val_loss: 0.7072 - val_accuracy: 0.8180
# Epoch 50/100
# 63/63 [==============================] - 35s 562ms/step - loss: 0.1954 - accuracy: 0.9205 - val_loss: 1.0716 - val_accuracy: 0.7790
# Epoch 51/100
# 63/63 [==============================] - 35s 562ms/step - loss: 0.1943 - accuracy: 0.9235 - val_loss: 0.5893 - val_accuracy: 0.8190
# Epoch 52/100
# 63/63 [==============================] - 35s 562ms/step - loss: 0.2179 - accuracy: 0.9160 - val_loss: 0.6536 - val_accuracy: 0.8010
# Epoch 53/100
# 63/63 [==============================] - 35s 562ms/step - loss: 0.2112 - accuracy: 0.9205 - val_loss: 0.6631 - val_accuracy: 0.8170
# Epoch 54/100
# 63/63 [==============================] - 35s 560ms/step - loss: 0.1798 - accuracy: 0.9280 - val_loss: 0.7666 - val_accuracy: 0.8090
# Epoch 55/100
# 63/63 [==============================] - 35s 563ms/step - loss: 0.1845 - accuracy: 0.9235 - val_loss: 0.7890 - val_accuracy: 0.7970
# Epoch 56/100
# 63/63 [==============================] - 35s 562ms/step - loss: 0.1737 - accuracy: 0.9345 - val_loss: 1.1851 - val_accuracy: 0.7950
# Epoch 57/100
# 63/63 [==============================] - 36s 572ms/step - loss: 0.1756 - accuracy: 0.9320 - val_loss: 0.7007 - val_accuracy: 0.8330
# Epoch 58/100
# 63/63 [==============================] - 36s 577ms/step - loss: 0.1598 - accuracy: 0.9410 - val_loss: 0.8256 - val_accuracy: 0.8190
# Epoch 59/100
# 63/63 [==============================] - 37s 592ms/step - loss: 0.1756 - accuracy: 0.9370 - val_loss: 0.6946 - val_accuracy: 0.8300
# Epoch 60/100
# 63/63 [==============================] - 37s 581ms/step - loss: 0.1518 - accuracy: 0.9445 - val_loss: 0.8091 - val_accuracy: 0.8120
# Epoch 61/100
# 63/63 [==============================] - 37s 583ms/step - loss: 0.1758 - accuracy: 0.9345 - val_loss: 0.7239 - val_accuracy: 0.7980
# Epoch 62/100
# 63/63 [==============================] - 37s 585ms/step - loss: 0.1639 - accuracy: 0.9410 - val_loss: 0.9543 - val_accuracy: 0.7900
# Epoch 63/100
# 63/63 [==============================] - 36s 577ms/step - loss: 0.1359 - accuracy: 0.9505 - val_loss: 0.7260 - val_accuracy: 0.8280
# Epoch 64/100
# 63/63 [==============================] - 36s 576ms/step - loss: 0.1580 - accuracy: 0.9460 - val_loss: 0.8743 - val_accuracy: 0.8110
# Epoch 65/100
# 63/63 [==============================] - 37s 591ms/step - loss: 0.1681 - accuracy: 0.9380 - val_loss: 1.3978 - val_accuracy: 0.7230
# Epoch 66/100
# 63/63 [==============================] - 36s 576ms/step - loss: 0.1487 - accuracy: 0.9470 - val_loss: 1.0475 - val_accuracy: 0.7940
# Epoch 67/100
# 63/63 [==============================] - 36s 575ms/step - loss: 0.1401 - accuracy: 0.9525 - val_loss: 0.8940 - val_accuracy: 0.8180
# Epoch 68/100
# 63/63 [==============================] - 36s 572ms/step - loss: 0.1415 - accuracy: 0.9540 - val_loss: 1.0125 - val_accuracy: 0.8140
# Epoch 69/100
# 63/63 [==============================] - 36s 573ms/step - loss: 0.1488 - accuracy: 0.9455 - val_loss: 1.0080 - val_accuracy: 0.7990
# Epoch 70/100
# 63/63 [==============================] - 36s 575ms/step - loss: 0.1580 - accuracy: 0.9465 - val_loss: 0.9593 - val_accuracy: 0.8220
# Epoch 71/100
# 63/63 [==============================] - 36s 576ms/step - loss: 0.1441 - accuracy: 0.9505 - val_loss: 0.7861 - val_accuracy: 0.8270
# Epoch 72/100
# 63/63 [==============================] - 36s 571ms/step - loss: 0.1444 - accuracy: 0.9510 - val_loss: 0.8699 - val_accuracy: 0.8290
# Epoch 73/100
# 63/63 [==============================] - 36s 576ms/step - loss: 0.1343 - accuracy: 0.9510 - val_loss: 1.0089 - val_accuracy: 0.7990
# Epoch 74/100
# 63/63 [==============================] - 36s 566ms/step - loss: 0.1698 - accuracy: 0.9430 - val_loss: 0.9085 - val_accuracy: 0.8150
# Epoch 75/100
# 63/63 [==============================] - 36s 568ms/step - loss: 0.1456 - accuracy: 0.9535 - val_loss: 0.8106 - val_accuracy: 0.8240
# Epoch 76/100
# 63/63 [==============================] - 36s 564ms/step - loss: 0.1353 - accuracy: 0.9525 - val_loss: 0.8035 - val_accuracy: 0.8210
# Epoch 77/100
# 63/63 [==============================] - 36s 573ms/step - loss: 0.1544 - accuracy: 0.9470 - val_loss: 1.1276 - val_accuracy: 0.8110
# Epoch 78/100
# 63/63 [==============================] - 36s 565ms/step - loss: 0.1458 - accuracy: 0.9560 - val_loss: 1.5095 - val_accuracy: 0.7820
# Epoch 79/100
# 63/63 [==============================] - 36s 564ms/step - loss: 0.1533 - accuracy: 0.9460 - val_loss: 1.0178 - val_accuracy: 0.8390
# Epoch 80/100
# 63/63 [==============================] - 36s 577ms/step - loss: 0.1618 - accuracy: 0.9495 - val_loss: 0.8032 - val_accuracy: 0.8140
# Epoch 81/100
# 63/63 [==============================] - 36s 573ms/step - loss: 0.1221 - accuracy: 0.9605 - val_loss: 1.1709 - val_accuracy: 0.8010
# Epoch 82/100
# 63/63 [==============================] - 36s 574ms/step - loss: 0.1597 - accuracy: 0.9530 - val_loss: 0.8565 - val_accuracy: 0.8260
# Epoch 83/100
# 63/63 [==============================] - 36s 575ms/step - loss: 0.1252 - accuracy: 0.9585 - val_loss: 1.1626 - val_accuracy: 0.8200
# Epoch 84/100
# 63/63 [==============================] - 36s 579ms/step - loss: 0.1301 - accuracy: 0.9630 - val_loss: 0.9443 - val_accuracy: 0.8320
# Epoch 85/100
# 63/63 [==============================] - 36s 573ms/step - loss: 0.1475 - accuracy: 0.9480 - val_loss: 0.7831 - val_accuracy: 0.8340
# Epoch 86/100
# 63/63 [==============================] - 36s 570ms/step - loss: 0.1458 - accuracy: 0.9520 - val_loss: 0.8740 - val_accuracy: 0.8210
# Epoch 87/100
# 63/63 [==============================] - 36s 573ms/step - loss: 0.1059 - accuracy: 0.9620 - val_loss: 0.8795 - val_accuracy: 0.8300
# Epoch 88/100
# 63/63 [==============================] - 36s 572ms/step - loss: 0.1257 - accuracy: 0.9570 - val_loss: 0.8475 - val_accuracy: 0.8360
# Epoch 89/100
# 63/63 [==============================] - 36s 572ms/step - loss: 0.1274 - accuracy: 0.9580 - val_loss: 1.0689 - val_accuracy: 0.8290
# Epoch 90/100
# 63/63 [==============================] - 36s 574ms/step - loss: 0.1393 - accuracy: 0.9550 - val_loss: 0.8472 - val_accuracy: 0.8420
# Epoch 91/100
# 63/63 [==============================] - 37s 592ms/step - loss: 0.1383 - accuracy: 0.9600 - val_loss: 0.9850 - val_accuracy: 0.8020
# Epoch 92/100
# 63/63 [==============================] - 36s 577ms/step - loss: 0.1545 - accuracy: 0.9600 - val_loss: 0.9569 - val_accuracy: 0.7890
# Epoch 93/100
# 63/63 [==============================] - 37s 586ms/step - loss: 0.1298 - accuracy: 0.9550 - val_loss: 1.3825 - val_accuracy: 0.8070
# Epoch 94/100
# 63/63 [==============================] - 36s 573ms/step - loss: 0.1159 - accuracy: 0.9635 - val_loss: 1.5314 - val_accuracy: 0.8180
# Epoch 95/100
# 63/63 [==============================] - 37s 586ms/step - loss: 0.1559 - accuracy: 0.9560 - val_loss: 0.9933 - val_accuracy: 0.8270
# Epoch 96/100
# 63/63 [==============================] - 37s 586ms/step - loss: 0.1260 - accuracy: 0.9605 - val_loss: 1.0850 - val_accuracy: 0.8190
# Epoch 97/100
# 63/63 [==============================] - 37s 589ms/step - loss: 0.1187 - accuracy: 0.9640 - val_loss: 0.9345 - val_accuracy: 0.8370
# Epoch 98/100
# 63/63 [==============================] - 38s 598ms/step - loss: 0.1338 - accuracy: 0.9540 - val_loss: 1.1620 - val_accuracy: 0.8300
# Epoch 99/100
# 63/63 [==============================] - 37s 588ms/step - loss: 0.1667 - accuracy: 0.9505 - val_loss: 1.0866 - val_accuracy: 0.8060
# Epoch 100/100
# 63/63 [==============================] - 36s 578ms/step - loss: 0.1110 - accuracy: 0.9595 - val_loss: 1.0834 - val_accuracy: 0.8270

# %% [markdown]
# **Evaluating the model on the test set**

# %%
test_model = keras.models.load_model(
    "convnet_from_scratch_with_augmentation.keras")
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 63/63 [==============================] - 7s 107ms/step - loss: 0.4894 - accuracy: 0.7745
# Test accuracy: 0.775

# %% [markdown]
# ## Leveraging a pretrained model

# %% [markdown]
# ### Feature extraction with a pretrained model

# %% [markdown]
# **Instantiating the VGG16 convolutional base**

# %%
conv_base = keras.applications.vgg16.VGG16(
    weights="imagenet",
    include_top=False,
    input_shape=(180, 180, 3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 1s 0us/step

# %%
conv_base.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 180, 180, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 180, 180, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 180, 180, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 90, 90, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 90, 90, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 90, 90, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 45, 45, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 45, 45, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 45, 45, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 45, 45, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 22, 22, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 22, 22, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 22, 22, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 22, 22, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 11, 11, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 11, 11, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 11, 11, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 11, 11, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 5, 5, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Fast feature extraction without data augmentation

# %% [markdown]
# **Extracting the VGG16 features and corresponding labels**

# %%
import numpy as np

def get_features_and_labels(dataset):
    all_features = []
    all_labels = []
    for images, labels in dataset:
        preprocessed_images = keras.applications.vgg16.preprocess_input(images)
        features = conv_base.predict(preprocessed_images)
        all_features.append(features)
        all_labels.append(labels)
    return np.concatenate(all_features), np.concatenate(all_labels)

train_features, train_labels =  get_features_and_labels(train_dataset)
val_features, val_labels =  get_features_and_labels(validation_dataset)
test_features, test_labels =  get_features_and_labels(test_dataset)
# Out:
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 689ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 323ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 621ms/step

# %%
train_features.shape
# Out:
# (2000, 5, 5, 512)

# %% [markdown]
# **Defining and training the densely connected classifier**

# %%
inputs = keras.Input(shape=(5, 5, 512))
x = layers.Flatten()(inputs)
x = layers.Dense(256)(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs, outputs)
model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

callbacks = [
    keras.callbacks.ModelCheckpoint(
      filepath="feature_extraction.keras",
      save_best_only=True,
      monitor="val_loss")
]
history = model.fit(
    train_features, train_labels,
    epochs=20,
    validation_data=(val_features, val_labels),
    callbacks=callbacks)
# Out:
# Epoch 1/20
# 63/63 [==============================] - 2s 26ms/step - loss: 16.3231 - accuracy: 0.9230 - val_loss: 3.6048 - val_accuracy: 0.9710
# Epoch 2/20
# 63/63 [==============================] - 1s 24ms/step - loss: 3.8664 - accuracy: 0.9790 - val_loss: 3.2470 - val_accuracy: 0.9780
# Epoch 3/20
# 63/63 [==============================] - 1s 23ms/step - loss: 1.5511 - accuracy: 0.9865 - val_loss: 3.9283 - val_accuracy: 0.9760
# Epoch 4/20
# 63/63 [==============================] - 1s 23ms/step - loss: 0.8883 - accuracy: 0.9910 - val_loss: 8.3497 - val_accuracy: 0.9640
# Epoch 5/20
# 63/63 [==============================] - 1s 23ms/step - loss: 0.4786 - accuracy: 0.9935 - val_loss: 3.6681 - val_accuracy: 0.9790
# Epoch 6/20
# 63/63 [==============================] - 1s 23ms/step - loss: 1.0706 - accuracy: 0.9920 - val_loss: 5.3023 - val_accuracy: 0.9680
# Epoch 7/20
# 63/63 [==============================] - 1s 23ms/step - loss: 0.3194 - accuracy: 0.9955 - val_loss: 3.8210 - val_accuracy: 0.9760
# Epoch 8/20
# 63/63 [==============================] - 1s 23ms/step - loss: 0.8469 - accuracy: 0.9910 - val_loss: 3.2006 - val_accuracy: 0.9750
# Epoch 9/20
# 63/63 [==============================] - 1s 23ms/step - loss: 0.0961 - accuracy: 0.9990 - val_loss: 3.8542 - val_accuracy: 0.9760
# Epoch 10/20
# 63/63 [==============================] - 1s 23ms/step - loss: 0.1583 - accuracy: 0.9975 - val_loss: 3.7018 - val_accuracy: 0.9790
# Epoch 11/20
# 63/63 [==============================] - 1s 23ms/step - loss: 0.0782 - accuracy: 0.9985 - val_loss: 3.7514 - val_accuracy: 0.9810
# Epoch 12/20
# 63/63 [==============================] - 1s 23ms/step - loss: 0.7826 - accuracy: 0.9955 - val_loss: 3.8434 - val_accuracy: 0.9790
# Epoch 13/20
# 63/63 [==============================] - 1s 23ms/step - loss: 0.0797 - accuracy: 0.9990 - val_loss: 4.4559 - val_accuracy: 0.9800
# Epoch 14/20
# 63/63 [==============================] - 1s 23ms/step - loss: 0.2424 - accuracy: 0.9980 - val_loss: 4.0850 - val_accuracy: 0.9780
# Epoch 15/20
# 63/63 [==============================] - 1s 24ms/step - loss: 0.1140 - accuracy: 0.9980 - val_loss: 4.2607 - val_accuracy: 0.9780
# Epoch 16/20
# 63/63 [==============================] - 1s 23ms/step - loss: 0.0886 - accuracy: 0.9990 - val_loss: 6.9827 - val_accuracy: 0.9700
# Epoch 17/20
# 63/63 [==============================] - 1s 22ms/step - loss: 0.2526 - accuracy: 0.9975 - val_loss: 5.0003 - val_accuracy: 0.9780
# Epoch 18/20
# 63/63 [==============================] - 1s 23ms/step - loss: 0.2435 - accuracy: 0.9985 - val_loss: 5.5952 - val_accuracy: 0.9780
# Epoch 19/20
# 63/63 [==============================] - 1s 22ms/step - loss: 0.0315 - accuracy: 0.9990 - val_loss: 4.3112 - val_accuracy: 0.9810
# Epoch 20/20
# 63/63 [==============================] - 1s 23ms/step - loss: 0.0267 - accuracy: 0.9995 - val_loss: 4.4520 - val_accuracy: 0.9780

# %% [markdown]
# **Plotting the results**

# %%
import matplotlib.pyplot as plt
acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(acc) + 1)
plt.plot(epochs, acc, "bo", label="Training accuracy")
plt.plot(epochs, val_acc, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %% [markdown]
# #### Feature extraction together with data augmentation

# %% [markdown]
# **Instantiating and freezing the VGG16 convolutional base**

# %%
conv_base  = keras.applications.vgg16.VGG16(
    weights="imagenet",
    include_top=False)
conv_base.trainable = False

# %% [markdown]
# **Printing the list of trainable weights before and after freezing**

# %%
conv_base.trainable = True
print("This is the number of trainable weights "
      "before freezing the conv base:", len(conv_base.trainable_weights))
# Out:
# This is the number of trainable weights before freezing the conv base: 26

# %%
conv_base.trainable = False
print("This is the number of trainable weights "
      "after freezing the conv base:", len(conv_base.trainable_weights))
# Out:
# This is the number of trainable weights after freezing the conv base: 0

# %% [markdown]
# **Adding a data augmentation stage and a classifier to the convolutional base**

# %%
data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.1),
        layers.RandomZoom(0.2),
    ]
)

inputs = keras.Input(shape=(180, 180, 3))
x = data_augmentation(inputs)
x = keras.applications.vgg16.preprocess_input(x)
x = conv_base(x)
x = layers.Flatten()(x)
x = layers.Dense(256)(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs, outputs)
model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="feature_extraction_with_data_augmentation.keras",
        save_best_only=True,
        monitor="val_loss")
]
history = model.fit(
    train_dataset,
    epochs=50,
    validation_data=validation_dataset,
    callbacks=callbacks)
# Out:
# Epoch 1/50
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# 63/63 [==============================] - 117s 2s/step - loss: 17.2131 - accuracy: 0.8945 - val_loss: 3.4107 - val_accuracy: 0.9770
# Epoch 2/50
# 63/63 [==============================] - 116s 2s/step - loss: 4.9253 - accuracy: 0.9565 - val_loss: 3.5967 - val_accuracy: 0.9700
# Epoch 3/50
# 63/63 [==============================] - 114s 2s/step - loss: 4.3401 - accuracy: 0.9610 - val_loss: 5.6260 - val_accuracy: 0.9680
# Epoch 4/50
# 63/63 [==============================] - 115s 2s/step - loss: 5.3333 - accuracy: 0.9605 - val_loss: 5.0589 - val_accuracy: 0.9740
# Epoch 5/50
# 63/63 [==============================] - 118s 2s/step - loss: 2.9685 - accuracy: 0.9740 - val_loss: 6.7878 - val_accuracy: 0.9690
# Epoch 6/50
# 63/63 [==============================] - 118s 2s/step - loss: 2.9225 - accuracy: 0.9770 - val_loss: 4.4583 - val_accuracy: 0.9720
# Epoch 7/50
# 63/63 [==============================] - 120s 2s/step - loss: 2.2076 - accuracy: 0.9755 - val_loss: 4.3844 - val_accuracy: 0.9720
# Epoch 8/50
# 63/63 [==============================] - 119s 2s/step - loss: 2.0316 - accuracy: 0.9765 - val_loss: 11.4727 - val_accuracy: 0.9520
# Epoch 9/50
# 63/63 [==============================] - 116s 2s/step - loss: 1.7071 - accuracy: 0.9820 - val_loss: 4.9270 - val_accuracy: 0.9700
# Epoch 10/50
# 63/63 [==============================] - 113s 2s/step - loss: 2.4166 - accuracy: 0.9780 - val_loss: 5.3197 - val_accuracy: 0.9670
# Epoch 11/50
# 63/63 [==============================] - 114s 2s/step - loss: 2.1656 - accuracy: 0.9750 - val_loss: 5.6104 - val_accuracy: 0.9720
# Epoch 12/50
# 63/63 [==============================] - 115s 2s/step - loss: 2.2014 - accuracy: 0.9815 - val_loss: 4.4667 - val_accuracy: 0.9750
# Epoch 13/50
# 63/63 [==============================] - 114s 2s/step - loss: 1.3774 - accuracy: 0.9855 - val_loss: 5.1308 - val_accuracy: 0.9710
# Epoch 14/50
# 63/63 [==============================] - 115s 2s/step - loss: 1.6558 - accuracy: 0.9800 - val_loss: 3.3979 - val_accuracy: 0.9720
# Epoch 15/50
# 63/63 [==============================] - 116s 2s/step - loss: 1.6851 - accuracy: 0.9850 - val_loss: 4.0395 - val_accuracy: 0.9720
# Epoch 16/50
# 63/63 [==============================] - 116s 2s/step - loss: 1.2501 - accuracy: 0.9865 - val_loss: 3.7291 - val_accuracy: 0.9750
# Epoch 17/50
# 63/63 [==============================] - 116s 2s/step - loss: 1.1574 - accuracy: 0.9870 - val_loss: 3.7774 - val_accuracy: 0.9730
# Epoch 18/50
# 63/63 [==============================] - 116s 2s/step - loss: 1.0200 - accuracy: 0.9835 - val_loss: 3.5661 - val_accuracy: 0.9730
# Epoch 19/50
# 63/63 [==============================] - 115s 2s/step - loss: 1.4397 - accuracy: 0.9810 - val_loss: 4.7354 - val_accuracy: 0.9670
# Epoch 20/50
# 63/63 [==============================] - 115s 2s/step - loss: 0.4309 - accuracy: 0.9900 - val_loss: 4.2094 - val_accuracy: 0.9750
# Epoch 21/50
# 63/63 [==============================] - 116s 2s/step - loss: 0.7435 - accuracy: 0.9895 - val_loss: 3.1143 - val_accuracy: 0.9790
# Epoch 22/50
# 63/63 [==============================] - 116s 2s/step - loss: 1.1000 - accuracy: 0.9870 - val_loss: 2.7814 - val_accuracy: 0.9780
# Epoch 23/50
# 63/63 [==============================] - 115s 2s/step - loss: 1.0908 - accuracy: 0.9885 - val_loss: 2.6237 - val_accuracy: 0.9790
# Epoch 24/50
# 63/63 [==============================] - 115s 2s/step - loss: 0.7540 - accuracy: 0.9885 - val_loss: 3.0145 - val_accuracy: 0.9780
# Epoch 25/50
# 63/63 [==============================] - 115s 2s/step - loss: 0.5255 - accuracy: 0.9940 - val_loss: 2.5938 - val_accuracy: 0.9770
# Epoch 26/50
# 63/63 [==============================] - 115s 2s/step - loss: 0.7127 - accuracy: 0.9845 - val_loss: 2.3142 - val_accuracy: 0.9810
# Epoch 27/50
# 63/63 [==============================] - 115s 2s/step - loss: 0.7835 - accuracy: 0.9910 - val_loss: 2.0269 - val_accuracy: 0.9820
# Epoch 28/50
# 63/63 [==============================] - 116s 2s/step - loss: 1.0139 - accuracy: 0.9875 - val_loss: 2.4714 - val_accuracy: 0.9760
# Epoch 29/50
# 63/63 [==============================] - 115s 2s/step - loss: 0.9473 - accuracy: 0.9900 - val_loss: 3.2650 - val_accuracy: 0.9750
# Epoch 30/50
# 63/63 [==============================] - 113s 2s/step - loss: 0.6431 - accuracy: 0.9910 - val_loss: 3.1436 - val_accuracy: 0.9750
# Epoch 31/50
# 63/63 [==============================] - 114s 2s/step - loss: 0.5144 - accuracy: 0.9925 - val_loss: 3.3386 - val_accuracy: 0.9740
# Epoch 32/50
# 63/63 [==============================] - 114s 2s/step - loss: 0.5008 - accuracy: 0.9910 - val_loss: 4.0781 - val_accuracy: 0.9740
# Epoch 33/50
# 63/63 [==============================] - 113s 2s/step - loss: 0.7182 - accuracy: 0.9895 - val_loss: 3.0350 - val_accuracy: 0.9750
# Epoch 34/50
# 63/63 [==============================] - 112s 2s/step - loss: 0.5523 - accuracy: 0.9935 - val_loss: 3.2717 - val_accuracy: 0.9760
# Epoch 35/50
# 63/63 [==============================] - 113s 2s/step - loss: 0.5597 - accuracy: 0.9885 - val_loss: 3.0948 - val_accuracy: 0.9780
# Epoch 36/50
# 63/63 [==============================] - 112s 2s/step - loss: 0.4459 - accuracy: 0.9915 - val_loss: 3.0596 - val_accuracy: 0.9780
# Epoch 37/50
# 63/63 [==============================] - 112s 2s/step - loss: 0.9952 - accuracy: 0.9890 - val_loss: 4.2992 - val_accuracy: 0.9700
# Epoch 38/50
# 63/63 [==============================] - 112s 2s/step - loss: 0.3226 - accuracy: 0.9965 - val_loss: 2.8854 - val_accuracy: 0.9770
# Epoch 39/50
# 63/63 [==============================] - 112s 2s/step - loss: 1.1333 - accuracy: 0.9875 - val_loss: 2.6633 - val_accuracy: 0.9780
# Epoch 40/50
# 63/63 [==============================] - 114s 2s/step - loss: 0.2398 - accuracy: 0.9950 - val_loss: 3.7703 - val_accuracy: 0.9780
# Epoch 41/50
# 63/63 [==============================] - 112s 2s/step - loss: 0.7245 - accuracy: 0.9920 - val_loss: 2.3364 - val_accuracy: 0.9820
# Epoch 42/50
# 63/63 [==============================] - 112s 2s/step - loss: 0.8596 - accuracy: 0.9910 - val_loss: 2.5100 - val_accuracy: 0.9790
# Epoch 43/50
# 63/63 [==============================] - 112s 2s/step - loss: 0.8566 - accuracy: 0.9900 - val_loss: 2.5195 - val_accuracy: 0.9820
# Epoch 44/50
# 63/63 [==============================] - 112s 2s/step - loss: 0.7253 - accuracy: 0.9895 - val_loss: 2.6257 - val_accuracy: 0.9800
# Epoch 45/50
# 63/63 [==============================] - 112s 2s/step - loss: 0.3527 - accuracy: 0.9910 - val_loss: 2.7009 - val_accuracy: 0.9800
# Epoch 46/50
# 63/63 [==============================] - 112s 2s/step - loss: 0.3427 - accuracy: 0.9950 - val_loss: 2.7686 - val_accuracy: 0.9770
# Epoch 47/50
# 63/63 [==============================] - 112s 2s/step - loss: 0.2900 - accuracy: 0.9930 - val_loss: 2.5475 - val_accuracy: 0.9760
# Epoch 48/50
# 63/63 [==============================] - 112s 2s/step - loss: 0.3393 - accuracy: 0.9935 - val_loss: 3.4596 - val_accuracy: 0.9770
# Epoch 49/50
# 63/63 [==============================] - 112s 2s/step - loss: 0.4042 - accuracy: 0.9925 - val_loss: 3.2260 - val_accuracy: 0.9770
# Epoch 50/50
# 63/63 [==============================] - 112s 2s/step - loss: 0.4568 - accuracy: 0.9935 - val_loss: 2.7969 - val_accuracy: 0.9780

# %% [markdown]
# **Evaluating the model on the test set**

# %%
test_model = keras.models.load_model(
    "feature_extraction_with_data_augmentation.keras")
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 63/63 [==============================] - 73s 1s/step - loss: 3.7690 - accuracy: 0.9740
# Test accuracy: 0.974

# %% [markdown]
# ### Fine-tuning a pretrained model

# %%
conv_base.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_7 (InputLayer)        [(None, None, None, 3)]   0
#
#  block1_conv1 (Conv2D)       (None, None, None, 64)    1792
#
#  block1_conv2 (Conv2D)       (None, None, None, 64)    36928
#
#  block1_pool (MaxPooling2D)  (None, None, None, 64)    0
#
#  block2_conv1 (Conv2D)       (None, None, None, 128)   73856
#
#  block2_conv2 (Conv2D)       (None, None, None, 128)   147584
#
#  block2_pool (MaxPooling2D)  (None, None, None, 128)   0
#
#  block3_conv1 (Conv2D)       (None, None, None, 256)   295168
#
#  block3_conv2 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_conv3 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_pool (MaxPooling2D)  (None, None, None, 256)   0
#
#  block4_conv1 (Conv2D)       (None, None, None, 512)   1180160
#
#  block4_conv2 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_conv3 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_pool (MaxPooling2D)  (None, None, None, 512)   0
#
#  block5_conv1 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv2 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv3 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_pool (MaxPooling2D)  (None, None, None, 512)   0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 0
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %% [markdown]
# **Freezing all layers until the fourth from the last**

# %%
conv_base.trainable = True
for layer in conv_base.layers[:-4]:
    layer.trainable = False

# %% [markdown]
# **Fine-tuning the model**

# %%
model.compile(loss="binary_crossentropy",
              optimizer=keras.optimizers.RMSprop(learning_rate=1e-5),
              metrics=["accuracy"])

callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="fine_tuning.keras",
        save_best_only=True,
        monitor="val_loss")
]
history = model.fit(
    train_dataset,
    epochs=30,
    validation_data=validation_dataset,
    callbacks=callbacks)
# Out:
# Epoch 1/30
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# 63/63 [==============================] - 241s 4s/step - loss: 2.9977 - accuracy: 0.9725 - val_loss: 2.9146 - val_accuracy: 0.9790
# Epoch 2/30
# 63/63 [==============================] - 223s 4s/step - loss: 2.7259 - accuracy: 0.9725 - val_loss: 3.0914 - val_accuracy: 0.9740
# Epoch 3/30
# 63/63 [==============================] - 222s 4s/step - loss: 1.4135 - accuracy: 0.9785 - val_loss: 2.0697 - val_accuracy: 0.9790
# Epoch 4/30
# 63/63 [==============================] - 220s 4s/step - loss: 1.0464 - accuracy: 0.9855 - val_loss: 2.8574 - val_accuracy: 0.9760
# Epoch 5/30
# 63/63 [==============================] - 223s 4s/step - loss: 0.8631 - accuracy: 0.9865 - val_loss: 2.4821 - val_accuracy: 0.9760
# Epoch 6/30
# 63/63 [==============================] - 223s 4s/step - loss: 0.7684 - accuracy: 0.9855 - val_loss: 1.8671 - val_accuracy: 0.9810
# Epoch 7/30
# 63/63 [==============================] - 226s 4s/step - loss: 0.7602 - accuracy: 0.9845 - val_loss: 1.8952 - val_accuracy: 0.9770
# Epoch 8/30
# 63/63 [==============================] - 218s 3s/step - loss: 0.5536 - accuracy: 0.9875 - val_loss: 1.8248 - val_accuracy: 0.9800
# Epoch 9/30
# 63/63 [==============================] - 219s 3s/step - loss: 0.3331 - accuracy: 0.9920 - val_loss: 1.3972 - val_accuracy: 0.9850
# Epoch 10/30
# 63/63 [==============================] - 215s 3s/step - loss: 0.3043 - accuracy: 0.9910 - val_loss: 1.8817 - val_accuracy: 0.9820
# Epoch 11/30
# 63/63 [==============================] - 215s 3s/step - loss: 0.0927 - accuracy: 0.9970 - val_loss: 1.7922 - val_accuracy: 0.9820
# Epoch 12/30
# 63/63 [==============================] - 218s 3s/step - loss: 0.4305 - accuracy: 0.9905 - val_loss: 1.7280 - val_accuracy: 0.9830
# Epoch 13/30
# 63/63 [==============================] - 213s 3s/step - loss: 0.4389 - accuracy: 0.9905 - val_loss: 1.7405 - val_accuracy: 0.9820
# Epoch 14/30
# 63/63 [==============================] - 218s 3s/step - loss: 0.4159 - accuracy: 0.9940 - val_loss: 1.4652 - val_accuracy: 0.9850
# Epoch 15/30
# 63/63 [==============================] - 219s 3s/step - loss: 0.2116 - accuracy: 0.9945 - val_loss: 1.6442 - val_accuracy: 0.9750
# Epoch 16/30
# 63/63 [==============================] - 216s 3s/step - loss: 0.1439 - accuracy: 0.9950 - val_loss: 1.5587 - val_accuracy: 0.9850
# Epoch 17/30
# 63/63 [==============================] - 212s 3s/step - loss: 0.2001 - accuracy: 0.9950 - val_loss: 1.3865 - val_accuracy: 0.9850
# Epoch 18/30
# 63/63 [==============================] - 214s 3s/step - loss: 0.1017 - accuracy: 0.9945 - val_loss: 1.5590 - val_accuracy: 0.9780
# Epoch 19/30
# 63/63 [==============================] - 213s 3s/step - loss: 0.1673 - accuracy: 0.9950 - val_loss: 1.5718 - val_accuracy: 0.9840
# Epoch 20/30
# 63/63 [==============================] - 213s 3s/step - loss: 0.2640 - accuracy: 0.9940 - val_loss: 1.6763 - val_accuracy: 0.9790
# Epoch 21/30
# 63/63 [==============================] - 214s 3s/step - loss: 0.3623 - accuracy: 0.9925 - val_loss: 1.8720 - val_accuracy: 0.9780
# Epoch 22/30
# 63/63 [==============================] - 218s 3s/step - loss: 0.2311 - accuracy: 0.9930 - val_loss: 1.6454 - val_accuracy: 0.9820
# Epoch 23/30
# 63/63 [==============================] - 212s 3s/step - loss: 0.1382 - accuracy: 0.9950 - val_loss: 1.7185 - val_accuracy: 0.9810
# Epoch 24/30
# 63/63 [==============================] - 216s 3s/step - loss: 0.0402 - accuracy: 0.9960 - val_loss: 1.6631 - val_accuracy: 0.9810
# Epoch 25/30
# 63/63 [==============================] - 209s 3s/step - loss: 0.2149 - accuracy: 0.9930 - val_loss: 1.8722 - val_accuracy: 0.9800
# Epoch 26/30
# 63/63 [==============================] - 204s 3s/step - loss: 0.0904 - accuracy: 0.9960 - val_loss: 2.9347 - val_accuracy: 0.9750
# Epoch 27/30
# 63/63 [==============================] - 210s 3s/step - loss: 0.0694 - accuracy: 0.9970 - val_loss: 1.9335 - val_accuracy: 0.9820
# Epoch 28/30
# 63/63 [==============================] - 209s 3s/step - loss: 0.2185 - accuracy: 0.9920 - val_loss: 2.3224 - val_accuracy: 0.9800
# Epoch 29/30
# 63/63 [==============================] - 213s 3s/step - loss: 0.0867 - accuracy: 0.9965 - val_loss: 2.0666 - val_accuracy: 0.9780
# Epoch 30/30
# 63/63 [==============================] - 207s 3s/step - loss: 0.1877 - accuracy: 0.9975 - val_loss: 2.2157 - val_accuracy: 0.9790

# %%
model = keras.models.load_model("fine_tuning.keras")
test_loss, test_acc = model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 63/63 [==============================] - 125s 2s/step - loss: 2.0821 - accuracy: 0.9795
# Test accuracy: 0.979

# %% [markdown]
# ## Summary
